# %%
# Define IAM role
import boto3
import re

import os
import numpy as np
import pandas as pd
from sagemaker import get_execution_role

role = get_execution_role()

# %%
import sagemaker
from time import gmtime, strftime

sess = sagemaker.LocalSession() # can use LocalSession() to run container locally

bucket = sess.default_bucket()
region = "us-east-2"
account = sess.boto_session.client('sts').get_caller_identity()['Account']
prefix_input = 'detectron2-input'
prefix_output = 'detectron2-ouput'

# %% [markdown]
# # Upload data for training

# %%
! ./upload_coco2017_to_s3.sh <your_bucket> <your_s3_path>

# %% [markdown]
# ## Push Docker image to registry
#
# For this training, we'll extend [Sagemaker PyTorch Container](https://docs.aws.amazon.com/deep-learning-containers/latest/devguide/deep-learning-containers-images.html) with Detectron2 dependencies (using official [D2 Dockerfile](https://github.com/facebookresearch/detectron2/blob/master/docker/Dockerfile)) as baseline. See Dockerfile below.

# %%
# !pygmentize Dockerfile
# Out:
# # Build an image of Detectron2 that can do
# # distributing training and inference in Amazon Sagemaker
#
# # using Sagemaker PyTorch container as base image
# FROM 763104351884.dkr.ecr.us-east-2.amazonaws.com/pytorch-training:1.4.0-gpu-py36-cu101-ubuntu16.04
# LABEL author="vadimd@amazon.com"
#
# ############# Installing latest builds ############
#
# # This is to fix issue: https://github.com/pytorch/vision/issues/1489
# RUN pip install --upgrade --force-reinstall torch torchvision cython
#
# ############# D2 section ##############
#
# # installing dependecies for D2 https://github.com/facebookresearch/detectron2/blob/master/docker/Dockerfile
# RUN pip install 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# RUN pip install 'git+https://github.com/facebookresearch/fvcore'
#
# ENV FORCE_CUDA="1"
# # Build D2 only for Volta architecture - V100 chips (ml.p3 AWS instances)
# ENV TORCH_CUDA_ARCH_LIST="Volta"
#
# # Build D2 from latest sources
# RUN pip install 'git+https://github.com/facebookresearch/detectron2.git'
#
# # Set a fixed model cache directory. Detectron2 requirement
# ENV FVCORE_CACHE="/tmp"
# # set location of training datasetm, Sagemaker containers copy all data from S3 to /opt/ml/input/data/{channels}
# ENV DETECTRON2_DATASETS="/opt/ml/input/data/training"
#
# ############# SageMaker section ##############
#
# COPY container_training /opt/ml/code
# WORKDIR /opt/ml/code
#
# # cloning D2 to code dir as we need access to default congigs
# RUN git clone 'https://github.com/facebookresearch/detectron2.git'
#
# ENV SAGEMAKER_SUBMIT_DIRECTORY /opt/ml/code
# ENV SAGEMAKER_PROGRAM train_coco.py
#
# WORKDIR /
#
# # Starts PyTorch distributed framework
# ENTRYPOINT ["bash", "-m", "start_with_right_hostname.sh"]

# %% [markdown]
# You'll need to build container from this Dockerfile and push it to Amazon Elastic Container Registry using `build_and_push.sh` script. But you'll need to loging to Sagemaker ECR and your private ECR first.

# %%
# loging to Sagemaker ECR with Deep Learning Containers
# !aws ecr get-login-password --region us-east-2 | docker login --username AWS --password-stdin 763104351884.dkr.ecr.us-east-2.amazonaws.com
# loging to your private ECR
# !aws ecr get-login-password --region us-east-2 | docker login --username AWS --password-stdin 553020858742.dkr.ecr.us-east-2.amazonaws.com
# Out:
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %% [markdown]
# Now you can ready to push your D2 container to private ECR

# %%
! ./build_and_push.sh d2-sm-coco distributed
# Out:
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# Sending build context to Docker daemon    360MB
# Step 1/17 : FROM 763104351884.dkr.ecr.us-east-2.amazonaws.com/pytorch-training:1.4.0-gpu-py36-cu101-ubuntu16.04
#  ---> 8433beacd261
# Step 2/17 : LABEL author="vadimd@amazon.com"
#  ---> Using cache
#  ---> 50a17efe355d
# Step 3/17 : RUN pip install --upgrade --force-reinstall torch torchvision cython
#  ---> Using cache
#  ---> f24cc7c56172
# Step 4/17 : RUN pip install 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
#  ---> Using cache
#  ---> 729a30eb3134
# Step 5/17 : RUN pip install 'git+https://github.com/facebookresearch/fvcore'
#  ---> Using cache
#  ---> 97d12e726ba8
# Step 6/17 : ENV FORCE_CUDA="1"
#  ---> Using cache
#  ---> 00333932bb38
# Step 7/17 : ENV TORCH_CUDA_ARCH_LIST="Volta"
#  ---> Using cache
#  ---> bc6648631b9e
# Step 8/17 : RUN pip install 'git+https://github.com/facebookresearch/detectron2.git'
#  ---> Using cache
#  ---> 5b0bb39cc802
# Step 9/17 : ENV FVCORE_CACHE="/tmp"
#  ---> Using cache
#  ---> 877355f8def1
# Step 10/17 : ENV DETECTRON2_DATASETS="/opt/ml/input/data/training"
#  ---> Using cache
#  ---> 949576cd1aaf
# Step 11/17 : COPY container_training /opt/ml/code
#  ---> 1ef8916ca87e
# Step 12/17 : WORKDIR /opt/ml/code
#  ---> Running in cd2946d1e391
# Removing intermediate container cd2946d1e391
#  ---> 0d886521b1f1
# Step 13/17 : RUN git clone 'https://github.com/facebookresearch/detectron2.git'
#  ---> Running in 8f9817f989ce
# Cloning into 'detectron2'...
# Removing intermediate container 8f9817f989ce
#  ---> 300d8e1a837c
# Step 14/17 : ENV SAGEMAKER_SUBMIT_DIRECTORY /opt/ml/code
#  ---> Running in 9c4e079388a6
# Removing intermediate container 9c4e079388a6
#  ---> 80751c22b945
# Step 15/17 : ENV SAGEMAKER_PROGRAM train_coco.py
#  ---> Running in 33f5e0f485fc
# Removing intermediate container 33f5e0f485fc
#  ---> 834da65b25fc
# Step 16/17 : WORKDIR /
#  ---> Running in 7c5a17ccdc97
# Removing intermediate container 7c5a17ccdc97
#  ---> acb026693f15
# Step 17/17 : ENTRYPOINT ["bash", "-m", "start_with_right_hostname.sh"]
#  ---> Running in 3296a34593b4
# Removing intermediate container 3296a34593b4
#  ---> 6302ec3a6df4
# Successfully built 6302ec3a6df4
# Successfully tagged d2-sm-coco:latest
# The push refers to repository [553020858742.dkr.ecr.us-east-2.amazonaws.com/d2-sm-coco]
#
# 1dc58329: Preparing
# 1c10e9de: Preparing
# 356479c5: Preparing
# 498b693e: Preparing
# f9b55c4c: Preparing
# f293f25a: Preparing
# 400f035c: Preparing
# 94948a0d: Preparing
# a2814a55: Preparing
# 23b5a57b: Preparing
# 738dc081: Preparing
# 055a69f0: Preparing
# 9876f35f: Preparing
# adb6f454: Preparing
# ebde6a27: Preparing
# 293f25a: Waiting g
# 4948a0d: Waiting g
# 82549d59: Waiting g
# 8d6db1d7: Preparing
# c1a50da0: Preparing
# 37055bb7: Preparing
# 1f4a2873: Preparing
# 1f4a2873: Waiting g
# 20da503d: Preparing
# dadd4466: Preparing
# 74e50f52: Preparing
# 9e8d85dd: Preparing
# 74ebe255: Preparing
# 9683cb41: Preparing
# 42719515: Preparing
# 103e78c9: Preparing
# e637fbff: Preparing
# dc58329: Pushed    6.33MBists 4MB3Adistributed: digest: sha256:8ba1efa86d893d580357cc65a889a823ed43bbb71b462aa6cd344883f15729a6 size: 7256

# %% [markdown]
# # Train your model

# %% [markdown]
# Define algorithm metrics which Sagemaker will scrap, persist, and render in training job console

# %%
container = "d2-sm-coco" # your container name
tag = "distributed"
image = '{}.dkr.ecr.{}.amazonaws.com/{}:{}'.format(account, region, container, tag)

# %%
metric_definitions=[
    {
        "Name": "total_loss",
        "Regex": ".*total_loss:\s([0-9\\.]+)\s*"
    },
    {
        "Name": "loss_cls",
        "Regex": ".*loss_cls:\s([0-9\\.]+)\s*"
    },
    {
        "Name": "loss_box_reg",
        "Regex": ".*loss_box_reg:\s([0-9\\.]+)\s*"
    },
    {
        "Name": "loss_mask",
        "Regex": ".*loss_mask:\s([0-9\\.]+)\s*"
    },
    {
        "Name": "loss_rpn_cls",
        "Regex": ".*loss_rpn_cls:\s([0-9\\.]+)\s*"
    },
    {
        "Name": "loss_rpn_loc",
        "Regex": ".*loss_rpn_loc:\s([0-9\\.]+)\s*"
    }, 
    {
        "Name": "overall_training_speed",
        "Regex": ".*Overall training speed:\s([0-9\\.]+)\s*"
    },
    {
        "Name": "lr",  
        "Regex": ".*lr:\s([0-9\\.]+)\s*"
    },
    {
        "Name": "iter",  
        "Regex": ".*iter:\s([0-9\\.]+)\s*"
    }
]

# %%
hyperparameters = {"config-file":"COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml", 
                   #"local-config-file" : "config.yaml", # if you'd like to supply custom config file, please it in container_training folder, and provide file name here
                   "resume":"False", # whether to re-use weights from pre-trained model
                   "eval-only":"False", # whether to perform only D2 model evaluation
                  # opts are D2 model configuration as defined here: https://detectron2.readthedocs.io/modules/config.html#config-references
                  # this is a way to override individual parameters in D2 configuration from Sagemaker API
#                   "opts": "DATALOADER.NUM_WORKERS 8"
                   }

    
d2 = sagemaker.estimator.Estimator(image,
                                   role=role,
                                   train_instance_count=2, 
                                   train_instance_type='ml.p3.16xlarge',
                                   train_instance_type="local_gpu", # use local_gpu for quick troubleshooting
                                   train_volume_size=100,
                                   output_path="s3://{}/{}".format(sess.default_bucket(), prefix_output),
                                   metric_definitions = metric_definitions,
                                   hyperparameters = hyperparameters, 
                                   tags=[{"Key":"Desc", "Value":"2 nodes"}],
                                   sagemaker_session=sess)

d2.fit({'training':"s3://coco2017-2a27f"}, wait=False)
# Out:
# Creating tmp6oge1eha_algo-1-v8gbf_1 ...
# Attaching to tmp6oge1eha_algo-1-v8gbf_12mdone
# algo-1-v8gbf_1  | 2020-04-28 20:16:45,430 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# algo-1-v8gbf_1  | 2020-04-28 20:16:45,431 sagemaker-containers INFO     Failed to parse hyperparameter config-file value COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml to Json.
# algo-1-v8gbf_1  | Returning the value itself
# algo-1-v8gbf_1  | 2020-04-28 20:16:45,431 sagemaker-containers INFO     Failed to parse hyperparameter resume value False to Json.
# algo-1-v8gbf_1  | Returning the value itself
# algo-1-v8gbf_1  | 2020-04-28 20:16:45,432 sagemaker-containers INFO     Failed to parse hyperparameter eval-only value False to Json.
# algo-1-v8gbf_1  | Returning the value itself
# algo-1-v8gbf_1  | 2020-04-28 20:16:45,459 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# algo-1-v8gbf_1  | 2020-04-28 20:16:45,463 sagemaker_pytorch_container.training INFO     Invoking user training script.
# algo-1-v8gbf_1  | 2020-04-28 20:16:45,538 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# algo-1-v8gbf_1  | Generating setup.py
# algo-1-v8gbf_1  | 2020-04-28 20:16:45,538 sagemaker-containers INFO     Generating setup.cfg
# algo-1-v8gbf_1  | 2020-04-28 20:16:45,539 sagemaker-containers INFO     Generating MANIFEST.in
# algo-1-v8gbf_1  | 2020-04-28 20:16:45,539 sagemaker-containers INFO     Installing module with the following command:
# algo-1-v8gbf_1  | /opt/conda/bin/python -m pip install .
# algo-1-v8gbf_1  | Processing /tmp/tmp62irhwfy/module_dir
# algo-1-v8gbf_1  | Building wheels for collected packages: default-user-module-name
# algo-1-v8gbf_1  |   Building wheel for default-user-module-name (setup.py) ... done
# algo-1-v8gbf_1  |   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=4356160 sha256=66036af479470c176f146251fa269e7eb8775ffbb46ef97079ef2d8071d384c4
# algo-1-v8gbf_1  |   Stored in directory: /tmp/pip-ephem-wheel-cache-ugxtou01/wheels/2b/19/46/54500ea218a2cc163551e6753d806d511ab52d618adb54ea9d
# algo-1-v8gbf_1  | Successfully built default-user-module-name
# algo-1-v8gbf_1  | Installing collected packages: default-user-module-name
# algo-1-v8gbf_1  | Successfully installed default-user-module-name-1.0.0
# algo-1-v8gbf_1  | 2020-04-28 20:16:48,862 sagemaker-containers INFO     Failed to parse hyperparameter config-file value COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml to Json.
# algo-1-v8gbf_1  | Returning the value itself
# algo-1-v8gbf_1  | 2020-04-28 20:16:48,862 sagemaker-containers INFO     Failed to parse hyperparameter resume value False to Json.
# algo-1-v8gbf_1  | Returning the value itself
# algo-1-v8gbf_1  | 2020-04-28 20:16:48,862 sagemaker-containers INFO     Failed to parse hyperparameter eval-only value False to Json.
# algo-1-v8gbf_1  | Returning the value itself
# algo-1-v8gbf_1  | 2020-04-28 20:16:48,878 sagemaker-containers INFO     Failed to parse hyperparameter config-file value COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml to Json.
# algo-1-v8gbf_1  | Returning the value itself
# algo-1-v8gbf_1  | 2020-04-28 20:16:48,878 sagemaker-containers INFO     Failed to parse hyperparameter resume value False to Json.
# algo-1-v8gbf_1  | Returning the value itself
# algo-1-v8gbf_1  | 2020-04-28 20:16:48,878 sagemaker-containers INFO     Failed to parse hyperparameter eval-only value False to Json.
# algo-1-v8gbf_1  | Returning the value itself
# algo-1-v8gbf_1  | 2020-04-28 20:16:48,907 sagemaker-containers INFO     Failed to parse hyperparameter config-file value COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml to Json.
# algo-1-v8gbf_1  | Returning the value itself
# algo-1-v8gbf_1  | 2020-04-28 20:16:48,907 sagemaker-containers INFO     Failed to parse hyperparameter resume value False to Json.
# algo-1-v8gbf_1  | Returning the value itself
# algo-1-v8gbf_1  | 2020-04-28 20:16:48,907 sagemaker-containers INFO     Failed to parse hyperparameter eval-only value False to Json.
# algo-1-v8gbf_1  | Returning the value itself
# algo-1-v8gbf_1  | 2020-04-28 20:16:48,935 sagemaker-containers INFO     Invoking user script
# algo-1-v8gbf_1  |
# algo-1-v8gbf_1  | Training Env:
# algo-1-v8gbf_1  |
# algo-1-v8gbf_1  | {
# algo-1-v8gbf_1  |     "additional_framework_parameters": {},
# algo-1-v8gbf_1  |     "channel_input_dirs": {},
# algo-1-v8gbf_1  |     "current_host": "algo-1-v8gbf",
# algo-1-v8gbf_1  |     "framework_module": "sagemaker_pytorch_container.training:main",
# algo-1-v8gbf_1  |     "hosts": [
# algo-1-v8gbf_1  |         "algo-1-v8gbf"
# algo-1-v8gbf_1  |     ],
# algo-1-v8gbf_1  |     "hyperparameters": {
# algo-1-v8gbf_1  |         "config-file": "COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml",
# algo-1-v8gbf_1  |         "resume": "False",
# algo-1-v8gbf_1  |         "eval-only": "False"
# algo-1-v8gbf_1  |     },
# algo-1-v8gbf_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-v8gbf_1  |     "input_data_config": {},
# algo-1-v8gbf_1  |     "input_dir": "/opt/ml/input",
# algo-1-v8gbf_1  |     "is_master": true,
# algo-1-v8gbf_1  |     "job_name": "d2-sm-coco-2020-04-28-20-16-42-899",
# algo-1-v8gbf_1  |     "log_level": 20,
# algo-1-v8gbf_1  |     "master_hostname": "algo-1-v8gbf",
# algo-1-v8gbf_1  |     "model_dir": "/opt/ml/model",
# algo-1-v8gbf_1  |     "module_dir": "/opt/ml/code",
# algo-1-v8gbf_1  |     "module_name": "train_coco",
# algo-1-v8gbf_1  |     "network_interface_name": "eth0",
# algo-1-v8gbf_1  |     "num_cpus": 4,
# algo-1-v8gbf_1  |     "num_gpus": 1,
# algo-1-v8gbf_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-v8gbf_1  |     "output_dir": "/opt/ml/output",
# algo-1-v8gbf_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-v8gbf_1  |     "resource_config": {
# algo-1-v8gbf_1  |         "current_host": "algo-1-v8gbf",
# algo-1-v8gbf_1  |         "hosts": [
# algo-1-v8gbf_1  |             "algo-1-v8gbf"
# algo-1-v8gbf_1  |         ]
# algo-1-v8gbf_1  |     },
# algo-1-v8gbf_1  |     "user_entry_point": "train_coco.py"
# algo-1-v8gbf_1  | }
# algo-1-v8gbf_1  |
# algo-1-v8gbf_1  | Environment variables:
# algo-1-v8gbf_1  |
# algo-1-v8gbf_1  | SM_HOSTS=["algo-1-v8gbf"]
# algo-1-v8gbf_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-v8gbf_1  | SM_HPS={"config-file":"COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml","eval-only":"False","resume":"False"}
# algo-1-v8gbf_1  | SM_USER_ENTRY_POINT=train_coco.py
# algo-1-v8gbf_1  | SM_FRAMEWORK_PARAMS={}
# algo-1-v8gbf_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-v8gbf","hosts":["algo-1-v8gbf"]}
# algo-1-v8gbf_1  | SM_INPUT_DATA_CONFIG={}
# algo-1-v8gbf_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-v8gbf_1  | SM_CHANNELS=[]
# algo-1-v8gbf_1  | SM_CURRENT_HOST=algo-1-v8gbf
# algo-1-v8gbf_1  | SM_MODULE_NAME=train_coco
# algo-1-v8gbf_1  | SM_LOG_LEVEL=20
# algo-1-v8gbf_1  | SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# algo-1-v8gbf_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-v8gbf_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-v8gbf_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-v8gbf_1  | SM_NUM_CPUS=4
# algo-1-v8gbf_1  | SM_NUM_GPUS=1
# algo-1-v8gbf_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-v8gbf_1  | SM_MODULE_DIR=/opt/ml/code
# algo-1-v8gbf_1  | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1-v8gbf","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1-v8gbf"],"hyperparameters":{"config-file":"COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml","eval-only":"False","resume":"False"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"d2-sm-coco-2020-04-28-20-16-42-899","log_level":20,"master_hostname":"algo-1-v8gbf","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"train_coco","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-v8gbf","hosts":["algo-1-v8gbf"]},"user_entry_point":"train_coco.py"}
# algo-1-v8gbf_1  | SM_USER_ARGS=["--config-file","COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml","--eval-only","False","--resume","False"]
# algo-1-v8gbf_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-v8gbf_1  | SM_HP_CONFIG-FILE=COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml
# algo-1-v8gbf_1  | SM_HP_RESUME=False
# algo-1-v8gbf_1  | SM_HP_EVAL-ONLY=False
# algo-1-v8gbf_1  | PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# algo-1-v8gbf_1  |
# algo-1-v8gbf_1  | Invoking script with the following command:
# algo-1-v8gbf_1  |
# algo-1-v8gbf_1  | /opt/conda/bin/python train_coco.py --config-file COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml --eval-only False --resume False
# algo-1-v8gbf_1  |
# algo-1-v8gbf_1  |
# algo-1-v8gbf_1  | Starting training...
# algo-1-v8gbf_1  | Running 'nccl' backend on 1 nodes and 1 processes. World size is 1.
# algo-1-v8gbf_1  | [04/28 20:16:51 detectron2]: Rank of current process: 0. World size: 1
# algo-1-v8gbf_1  | [04/28 20:16:51 detectron2]: Rank of current process: 0. World size: 1
# algo-1-v8gbf_1  | [04/28 20:16:51 detectron2]: Environment info:
# algo-1-v8gbf_1  | ------------------------  -------------------------------------------------------------------
# algo-1-v8gbf_1  | sys.platform              linux
# algo-1-v8gbf_1  | Python                    3.6.6 |Anaconda, Inc.| (default, Oct  9 2018, 12:34:16) [GCC 7.3.0]
# algo-1-v8gbf_1  | numpy                     1.18.3
# algo-1-v8gbf_1  | detectron2                0.1.1 @/opt/conda/lib/python3.6/site-packages/detectron2
# algo-1-v8gbf_1  | detectron2 compiler       GCC 5.4
# algo-1-v8gbf_1  | detectron2 CUDA compiler  10.1
# algo-1-v8gbf_1  | detectron2 arch flags     sm_70
# algo-1-v8gbf_1  | DETECTRON2_ENV_MODULE     <not set>
# algo-1-v8gbf_1  | PyTorch                   1.5.0 @/opt/conda/lib/python3.6/site-packages/torch
# algo-1-v8gbf_1  | PyTorch debug build       False
# algo-1-v8gbf_1  | CUDA available            True
# algo-1-v8gbf_1  | GPU 0                     Tesla K80
# algo-1-v8gbf_1  | CUDA_HOME                 /usr/local/cuda
# algo-1-v8gbf_1  | NVCC                      Cuda compilation tools, release 10.1, V10.1.243
# algo-1-v8gbf_1  | TORCH_CUDA_ARCH_LIST      Volta
# algo-1-v8gbf_1  | Pillow                    7.1.2
# algo-1-v8gbf_1  | torchvision               0.6.0 @/opt/conda/lib/python3.6/site-packages/torchvision
# algo-1-v8gbf_1  | torchvision arch flags    sm_35, sm_50, sm_60, sm_70, sm_75
# algo-1-v8gbf_1  | fvcore                    0.1
# algo-1-v8gbf_1  | cv2                       4.0.1
# algo-1-v8gbf_1  | ------------------------  -------------------------------------------------------------------
# algo-1-v8gbf_1  | PyTorch built with:
# algo-1-v8gbf_1  |   - GCC 7.3
# algo-1-v8gbf_1  |   - C++ Version: 201402
# algo-1-v8gbf_1  |   - Intel(R) Math Kernel Library Version 2019.0.5 Product Build 20190808 for Intel(R) 64 architecture applications
# algo-1-v8gbf_1  |   - Intel(R) MKL-DNN v0.21.1 (Git Hash 7d2fd500bc78936d1d648ca713b901012f470dbc)
# algo-1-v8gbf_1  |   - OpenMP 201511 (a.k.a. OpenMP 4.5)
# algo-1-v8gbf_1  |   - NNPACK is enabled
# algo-1-v8gbf_1  |   - CPU capability usage: AVX2
# algo-1-v8gbf_1  |   - CUDA Runtime 10.2
# algo-1-v8gbf_1  |   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_37,code=compute_37
# algo-1-v8gbf_1  |   - CuDNN 7.6.5
# algo-1-v8gbf_1  |   - Magma 2.5.2
# algo-1-v8gbf_1  |   - Build settings: BLAS=MKL, BUILD_TYPE=Release, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -fopenmp -DNDEBUG -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DUSE_INTERNAL_THREADPOOL_IMPL -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, USE_CUDA=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_STATIC_DISPATCH=OFF,
# algo-1-v8gbf_1  |
# algo-1-v8gbf_1  | [04/28 20:16:51 detectron2]: Environment info:
# algo-1-v8gbf_1  | ------------------------  -------------------------------------------------------------------
# algo-1-v8gbf_1  | sys.platform              linux
# algo-1-v8gbf_1  | Python                    3.6.6 |Anaconda, Inc.| (default, Oct  9 2018, 12:34:16) [GCC 7.3.0]
# algo-1-v8gbf_1  | numpy                     1.18.3
# algo-1-v8gbf_1  | detectron2                0.1.1 @/opt/conda/lib/python3.6/site-packages/detectron2
# algo-1-v8gbf_1  | detectron2 compiler       GCC 5.4
# algo-1-v8gbf_1  | detectron2 CUDA compiler  10.1
# algo-1-v8gbf_1  | detectron2 arch flags     sm_70
# algo-1-v8gbf_1  | DETECTRON2_ENV_MODULE     <not set>
# algo-1-v8gbf_1  | PyTorch                   1.5.0 @/opt/conda/lib/python3.6/site-packages/torch
# algo-1-v8gbf_1  | PyTorch debug build       False
# algo-1-v8gbf_1  | CUDA available            True
# algo-1-v8gbf_1  | GPU 0                     Tesla K80
# algo-1-v8gbf_1  | CUDA_HOME                 /usr/local/cuda
# algo-1-v8gbf_1  | NVCC                      Cuda compilation tools, release 10.1, V10.1.243
# algo-1-v8gbf_1  | TORCH_CUDA_ARCH_LIST      Volta
# algo-1-v8gbf_1  | Pillow                    7.1.2
# algo-1-v8gbf_1  | torchvision               0.6.0 @/opt/conda/lib/python3.6/site-packages/torchvision
# algo-1-v8gbf_1  | torchvision arch flags    sm_35, sm_50, sm_60, sm_70, sm_75
# algo-1-v8gbf_1  | fvcore                    0.1
# algo-1-v8gbf_1  | cv2                       4.0.1
# algo-1-v8gbf_1  | ------------------------  -------------------------------------------------------------------
# algo-1-v8gbf_1  | PyTorch built with:
# algo-1-v8gbf_1  |   - GCC 7.3
# algo-1-v8gbf_1  |   - C++ Version: 201402
# algo-1-v8gbf_1  |   - Intel(R) Math Kernel Library Version 2019.0.5 Product Build 20190808 for Intel(R) 64 architecture applications
# algo-1-v8gbf_1  |   - Intel(R) MKL-DNN v0.21.1 (Git Hash 7d2fd500bc78936d1d648ca713b901012f470dbc)
# algo-1-v8gbf_1  |   - OpenMP 201511 (a.k.a. OpenMP 4.5)
# algo-1-v8gbf_1  |   - NNPACK is enabled
# algo-1-v8gbf_1  |   - CPU capability usage: AVX2
# algo-1-v8gbf_1  |   - CUDA Runtime 10.2
# algo-1-v8gbf_1  |   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_37,code=compute_37
# algo-1-v8gbf_1  |   - CuDNN 7.6.5
# algo-1-v8gbf_1  |   - Magma 2.5.2
# algo-1-v8gbf_1  |   - Build settings: BLAS=MKL, BUILD_TYPE=Release, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -fopenmp -DNDEBUG -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DUSE_INTERNAL_THREADPOOL_IMPL -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, USE_CUDA=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_STATIC_DISPATCH=OFF,
# algo-1-v8gbf_1  |
# algo-1-v8gbf_1  | [04/28 20:16:51 detectron2]: Command line arguments: Namespace(config_file='/opt/ml/code/detectron2/configs/COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml', eval_only='False', opts=None, resume='False')
# algo-1-v8gbf_1  | [04/28 20:16:51 detectron2]: Command line arguments: Namespace(config_file='/opt/ml/code/detectron2/configs/COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml', eval_only='False', opts=None, resume='False')
# algo-1-v8gbf_1  | [04/28 20:16:51 detectron2]: Contents of args.config_file=/opt/ml/code/detectron2/configs/COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml:
# algo-1-v8gbf_1  | _BASE_: "../Base-RCNN-C4.yaml"
# algo-1-v8gbf_1  | MODEL:
# algo-1-v8gbf_1  |   WEIGHTS: "detectron2://ImageNetPretrained/MSRA/R-101.pkl"
# algo-1-v8gbf_1  |   MASK_ON: True
# algo-1-v8gbf_1  |   RESNETS:
# algo-1-v8gbf_1  |     DEPTH: 101
# algo-1-v8gbf_1  | SOLVER:
# algo-1-v8gbf_1  |   STEPS: (210000, 250000)
# algo-1-v8gbf_1  |   MAX_ITER: 270000
# algo-1-v8gbf_1  |
# algo-1-v8gbf_1  | [04/28 20:16:51 detectron2]: Contents of args.config_file=/opt/ml/code/detectron2/configs/COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml:
# algo-1-v8gbf_1  | _BASE_: "../Base-RCNN-C4.yaml"
# algo-1-v8gbf_1  | MODEL:
# algo-1-v8gbf_1  |   WEIGHTS: "detectron2://ImageNetPretrained/MSRA/R-101.pkl"
# algo-1-v8gbf_1  |   MASK_ON: True
# algo-1-v8gbf_1  |   RESNETS:
# algo-1-v8gbf_1  |     DEPTH: 101
# algo-1-v8gbf_1  | SOLVER:
# algo-1-v8gbf_1  |   STEPS: (210000, 250000)
# algo-1-v8gbf_1  |   MAX_ITER: 270000
# algo-1-v8gbf_1  |
# algo-1-v8gbf_1  | [04/28 20:16:51 detectron2]: Running with full config:
# algo-1-v8gbf_1  | CUDNN_BENCHMARK: False
# algo-1-v8gbf_1  | DATALOADER:
# algo-1-v8gbf_1  |   ASPECT_RATIO_GROUPING: True
# algo-1-v8gbf_1  |   FILTER_EMPTY_ANNOTATIONS: True
# algo-1-v8gbf_1  |   NUM_WORKERS: 4
# algo-1-v8gbf_1  |   REPEAT_THRESHOLD: 0.0
# algo-1-v8gbf_1  |   SAMPLER_TRAIN: TrainingSampler
# algo-1-v8gbf_1  | DATASETS:
# algo-1-v8gbf_1  |   PRECOMPUTED_PROPOSAL_TOPK_TEST: 1000
# algo-1-v8gbf_1  |   PRECOMPUTED_PROPOSAL_TOPK_TRAIN: 2000
# algo-1-v8gbf_1  |   PROPOSAL_FILES_TEST: ()
# algo-1-v8gbf_1  |   PROPOSAL_FILES_TRAIN: ()
# algo-1-v8gbf_1  |   TEST: ('coco_2017_val',)
# algo-1-v8gbf_1  |   TRAIN: ('coco_2017_train',)
# algo-1-v8gbf_1  | GLOBAL:
# algo-1-v8gbf_1  |   HACK: 1.0
# algo-1-v8gbf_1  | INPUT:
# algo-1-v8gbf_1  |   CROP:
# algo-1-v8gbf_1  |     ENABLED: False
# algo-1-v8gbf_1  |     SIZE: [0.9, 0.9]
# algo-1-v8gbf_1  |     TYPE: relative_range
# algo-1-v8gbf_1  |   FORMAT: BGR
# algo-1-v8gbf_1  |   MASK_FORMAT: polygon
# algo-1-v8gbf_1  |   MAX_SIZE_TEST: 1333
# algo-1-v8gbf_1  |   MAX_SIZE_TRAIN: 1333
# algo-1-v8gbf_1  |   MIN_SIZE_TEST: 800
# algo-1-v8gbf_1  |   MIN_SIZE_TRAIN: (640, 672, 704, 736, 768, 800)
# algo-1-v8gbf_1  |   MIN_SIZE_TRAIN_SAMPLING: choice
# algo-1-v8gbf_1  | MODEL:
# algo-1-v8gbf_1  |   ANCHOR_GENERATOR:
# algo-1-v8gbf_1  |     ANGLES: [[-90, 0, 90]]
# algo-1-v8gbf_1  |     ASPECT_RATIOS: [[0.5, 1.0, 2.0]]
# algo-1-v8gbf_1  |     NAME: DefaultAnchorGenerator
# algo-1-v8gbf_1  |     OFFSET: 0.0
# algo-1-v8gbf_1  |     SIZES: [[32, 64, 128, 256, 512]]
# algo-1-v8gbf_1  |   BACKBONE:
# algo-1-v8gbf_1  |     FREEZE_AT: 2
# algo-1-v8gbf_1  |     NAME: build_resnet_backbone
# algo-1-v8gbf_1  |   DEVICE: cuda
# algo-1-v8gbf_1  |   FPN:
# algo-1-v8gbf_1  |     FUSE_TYPE: sum
# algo-1-v8gbf_1  |     IN_FEATURES: []
# algo-1-v8gbf_1  |     NORM:
# algo-1-v8gbf_1  |     OUT_CHANNELS: 256
# algo-1-v8gbf_1  |   KEYPOINT_ON: False
# algo-1-v8gbf_1  |   LOAD_PROPOSALS: False
# algo-1-v8gbf_1  |   MASK_ON: True
# algo-1-v8gbf_1  |   META_ARCHITECTURE: GeneralizedRCNN
# algo-1-v8gbf_1  |   PANOPTIC_FPN:
# algo-1-v8gbf_1  |     COMBINE:
# algo-1-v8gbf_1  |       ENABLED: True
# algo-1-v8gbf_1  |       INSTANCES_CONFIDENCE_THRESH: 0.5
# algo-1-v8gbf_1  |       OVERLAP_THRESH: 0.5
# algo-1-v8gbf_1  |       STUFF_AREA_LIMIT: 4096
# algo-1-v8gbf_1  |     INSTANCE_LOSS_WEIGHT: 1.0
# algo-1-v8gbf_1  |   PIXEL_MEAN: [103.53, 116.28, 123.675]
# algo-1-v8gbf_1  |   PIXEL_STD: [1.0, 1.0, 1.0]
# algo-1-v8gbf_1  |   PROPOSAL_GENERATOR:
# algo-1-v8gbf_1  |     MIN_SIZE: 0
# algo-1-v8gbf_1  |     NAME: RPN
# algo-1-v8gbf_1  |   RESNETS:
# algo-1-v8gbf_1  |     DEFORM_MODULATED: False
# algo-1-v8gbf_1  |     DEFORM_NUM_GROUPS: 1
# algo-1-v8gbf_1  |     DEFORM_ON_PER_STAGE: [False, False, False, False]
# algo-1-v8gbf_1  |     DEPTH: 101
# algo-1-v8gbf_1  |     NORM: FrozenBN
# algo-1-v8gbf_1  |     NUM_GROUPS: 1
# algo-1-v8gbf_1  |     OUT_FEATURES: ['res4']
# algo-1-v8gbf_1  |     RES2_OUT_CHANNELS: 256
# algo-1-v8gbf_1  |     RES5_DILATION: 1
# algo-1-v8gbf_1  |     STEM_OUT_CHANNELS: 64
# algo-1-v8gbf_1  |     STRIDE_IN_1X1: True
# algo-1-v8gbf_1  |     WIDTH_PER_GROUP: 64
# algo-1-v8gbf_1  |   RETINANET:
# algo-1-v8gbf_1  |     BBOX_REG_WEIGHTS: (1.0, 1.0, 1.0, 1.0)
# algo-1-v8gbf_1  |     FOCAL_LOSS_ALPHA: 0.25
# algo-1-v8gbf_1  |     FOCAL_LOSS_GAMMA: 2.0
# algo-1-v8gbf_1  |     IN_FEATURES: ['p3', 'p4', 'p5', 'p6', 'p7']
# algo-1-v8gbf_1  |     IOU_LABELS: [0, -1, 1]
# algo-1-v8gbf_1  |     IOU_THRESHOLDS: [0.4, 0.5]
# algo-1-v8gbf_1  |     NMS_THRESH_TEST: 0.5
# algo-1-v8gbf_1  |     NUM_CLASSES: 80
# algo-1-v8gbf_1  |     NUM_CONVS: 4
# algo-1-v8gbf_1  |     PRIOR_PROB: 0.01
# algo-1-v8gbf_1  |     SCORE_THRESH_TEST: 0.05
# algo-1-v8gbf_1  |     SMOOTH_L1_LOSS_BETA: 0.1
# algo-1-v8gbf_1  |     TOPK_CANDIDATES_TEST: 1000
# algo-1-v8gbf_1  |   ROI_BOX_CASCADE_HEAD:
# algo-1-v8gbf_1  |     BBOX_REG_WEIGHTS: ((10.0, 10.0, 5.0, 5.0), (20.0, 20.0, 10.0, 10.0), (30.0, 30.0, 15.0, 15.0))
# algo-1-v8gbf_1  |     IOUS: (0.5, 0.6, 0.7)
# algo-1-v8gbf_1  |   ROI_BOX_HEAD:
# algo-1-v8gbf_1  |     BBOX_REG_WEIGHTS: (10.0, 10.0, 5.0, 5.0)
# algo-1-v8gbf_1  |     CLS_AGNOSTIC_BBOX_REG: False
# algo-1-v8gbf_1  |     CONV_DIM: 256
# algo-1-v8gbf_1  |     FC_DIM: 1024
# algo-1-v8gbf_1  |     NAME:
# algo-1-v8gbf_1  |     NORM:
# algo-1-v8gbf_1  |     NUM_CONV: 0
# algo-1-v8gbf_1  |     NUM_FC: 0
# algo-1-v8gbf_1  |     POOLER_RESOLUTION: 14
# algo-1-v8gbf_1  |     POOLER_SAMPLING_RATIO: 0
# algo-1-v8gbf_1  |     POOLER_TYPE: ROIAlignV2
# algo-1-v8gbf_1  |     SMOOTH_L1_BETA: 0.0
# algo-1-v8gbf_1  |     TRAIN_ON_PRED_BOXES: False
# algo-1-v8gbf_1  |   ROI_HEADS:
# algo-1-v8gbf_1  |     BATCH_SIZE_PER_IMAGE: 512
# algo-1-v8gbf_1  |     IN_FEATURES: ['res4']
# algo-1-v8gbf_1  |     IOU_LABELS: [0, 1]
# algo-1-v8gbf_1  |     IOU_THRESHOLDS: [0.5]
# algo-1-v8gbf_1  |     NAME: Res5ROIHeads
# algo-1-v8gbf_1  |     NMS_THRESH_TEST: 0.5
# algo-1-v8gbf_1  |     NUM_CLASSES: 80
# algo-1-v8gbf_1  |     POSITIVE_FRACTION: 0.25
# algo-1-v8gbf_1  |     PROPOSAL_APPEND_GT: True
# algo-1-v8gbf_1  |     SCORE_THRESH_TEST: 0.05
# algo-1-v8gbf_1  |   ROI_KEYPOINT_HEAD:
# algo-1-v8gbf_1  |     CONV_DIMS: (512, 512, 512, 512, 512, 512, 512, 512)
# algo-1-v8gbf_1  |     LOSS_WEIGHT: 1.0
# algo-1-v8gbf_1  |     MIN_KEYPOINTS_PER_IMAGE: 1
# algo-1-v8gbf_1  |     NAME: KRCNNConvDeconvUpsampleHead
# algo-1-v8gbf_1  |     NORMALIZE_LOSS_BY_VISIBLE_KEYPOINTS: True
# algo-1-v8gbf_1  |     NUM_KEYPOINTS: 17
# algo-1-v8gbf_1  |     POOLER_RESOLUTION: 14
# algo-1-v8gbf_1  |     POOLER_SAMPLING_RATIO: 0
# algo-1-v8gbf_1  |     POOLER_TYPE: ROIAlignV2
# algo-1-v8gbf_1  |   ROI_MASK_HEAD:
# algo-1-v8gbf_1  |     CLS_AGNOSTIC_MASK: False
# algo-1-v8gbf_1  |     CONV_DIM: 256
# algo-1-v8gbf_1  |     NAME: MaskRCNNConvUpsampleHead
# algo-1-v8gbf_1  |     NORM:
# algo-1-v8gbf_1  |     NUM_CONV: 0
# algo-1-v8gbf_1  |     POOLER_RESOLUTION: 14
# algo-1-v8gbf_1  |     POOLER_SAMPLING_RATIO: 0
# algo-1-v8gbf_1  |     POOLER_TYPE: ROIAlignV2
# algo-1-v8gbf_1  |   RPN:
# algo-1-v8gbf_1  |     BATCH_SIZE_PER_IMAGE: 256
# algo-1-v8gbf_1  |     BBOX_REG_WEIGHTS: (1.0, 1.0, 1.0, 1.0)
# algo-1-v8gbf_1  |     BOUNDARY_THRESH: -1
# algo-1-v8gbf_1  |     HEAD_NAME: StandardRPNHead
# algo-1-v8gbf_1  |     IN_FEATURES: ['res4']
# algo-1-v8gbf_1  |     IOU_LABELS: [0, -1, 1]
# algo-1-v8gbf_1  |     IOU_THRESHOLDS: [0.3, 0.7]
# algo-1-v8gbf_1  |     LOSS_WEIGHT: 1.0
# algo-1-v8gbf_1  |     NMS_THRESH: 0.7
# algo-1-v8gbf_1  |     POSITIVE_FRACTION: 0.5
# algo-1-v8gbf_1  |     POST_NMS_TOPK_TEST: 1000
# algo-1-v8gbf_1  |     POST_NMS_TOPK_TRAIN: 2000
# algo-1-v8gbf_1  |     PRE_NMS_TOPK_TEST: 6000
# algo-1-v8gbf_1  |     PRE_NMS_TOPK_TRAIN: 12000
# algo-1-v8gbf_1  |     SMOOTH_L1_BETA: 0.0
# algo-1-v8gbf_1  |   SEM_SEG_HEAD:
# algo-1-v8gbf_1  |     COMMON_STRIDE: 4
# algo-1-v8gbf_1  |     CONVS_DIM: 128
# algo-1-v8gbf_1  |     IGNORE_VALUE: 255
# algo-1-v8gbf_1  |     IN_FEATURES: ['p2', 'p3', 'p4', 'p5']
# algo-1-v8gbf_1  |     LOSS_WEIGHT: 1.0
# algo-1-v8gbf_1  |     NAME: SemSegFPNHead
# algo-1-v8gbf_1  |     NORM: GN
# algo-1-v8gbf_1  |     NUM_CLASSES: 54
# algo-1-v8gbf_1  |   WEIGHTS: detectron2://ImageNetPretrained/MSRA/R-101.pkl
# algo-1-v8gbf_1  | OUTPUT_DIR: /opt/ml/output/data
# algo-1-v8gbf_1  | SEED: -1
# algo-1-v8gbf_1  | SOLVER:
# algo-1-v8gbf_1  |   BASE_LR: 0.02
# algo-1-v8gbf_1  |   BIAS_LR_FACTOR: 1.0
# algo-1-v8gbf_1  |   CHECKPOINT_PERIOD: 5000
# algo-1-v8gbf_1  |   CLIP_GRADIENTS:
# algo-1-v8gbf_1  |     CLIP_TYPE: value
# algo-1-v8gbf_1  |     CLIP_VALUE: 1.0
# algo-1-v8gbf_1  |     ENABLED: False
# algo-1-v8gbf_1  |     NORM_TYPE: 2.0
# algo-1-v8gbf_1  |   GAMMA: 0.1
# algo-1-v8gbf_1  |   IMS_PER_BATCH: 1
# algo-1-v8gbf_1  |   LR_SCHEDULER_NAME: WarmupMultiStepLR
# algo-1-v8gbf_1  |   MAX_ITER: 270000
# algo-1-v8gbf_1  |   MOMENTUM: 0.9
# algo-1-v8gbf_1  |   STEPS: (210000, 250000)
# algo-1-v8gbf_1  |   WARMUP_FACTOR: 0.001
# algo-1-v8gbf_1  |   WARMUP_ITERS: 1000
# algo-1-v8gbf_1  |   WARMUP_METHOD: linear
# algo-1-v8gbf_1  |   WEIGHT_DECAY: 0.0001
# algo-1-v8gbf_1  |   WEIGHT_DECAY_BIAS: 0.0001
# algo-1-v8gbf_1  |   WEIGHT_DECAY_NORM: 0.0
# algo-1-v8gbf_1  | TEST:
# algo-1-v8gbf_1  |   AUG:
# algo-1-v8gbf_1  |     ENABLED: False
# algo-1-v8gbf_1  |     FLIP: True
# algo-1-v8gbf_1  |     MAX_SIZE: 4000
# algo-1-v8gbf_1  |     MIN_SIZES: (400, 500, 600, 700, 800, 900, 1000, 1100, 1200)
# algo-1-v8gbf_1  |   DETECTIONS_PER_IMAGE: 100
# algo-1-v8gbf_1  |   EVAL_PERIOD: 0
# algo-1-v8gbf_1  |   EXPECTED_RESULTS: []
# algo-1-v8gbf_1  |   KEYPOINT_OKS_SIGMAS: []
# algo-1-v8gbf_1  |   PRECISE_BN:
# algo-1-v8gbf_1  |     ENABLED: False
# algo-1-v8gbf_1  |     NUM_ITER: 200
# algo-1-v8gbf_1  | VERSION: 2
# algo-1-v8gbf_1  | VIS_PERIOD: 0
# algo-1-v8gbf_1  | [04/28 20:16:51 detectron2]: Running with full config:
# algo-1-v8gbf_1  | CUDNN_BENCHMARK: False
# algo-1-v8gbf_1  | DATALOADER:
# algo-1-v8gbf_1  |   ASPECT_RATIO_GROUPING: True
# algo-1-v8gbf_1  |   FILTER_EMPTY_ANNOTATIONS: True
# algo-1-v8gbf_1  |   NUM_WORKERS: 4
# algo-1-v8gbf_1  |   REPEAT_THRESHOLD: 0.0
# algo-1-v8gbf_1  |   SAMPLER_TRAIN: TrainingSampler
# algo-1-v8gbf_1  | DATASETS:
# algo-1-v8gbf_1  |   PRECOMPUTED_PROPOSAL_TOPK_TEST: 1000
# algo-1-v8gbf_1  |   PRECOMPUTED_PROPOSAL_TOPK_TRAIN: 2000
# algo-1-v8gbf_1  |   PROPOSAL_FILES_TEST: ()
# algo-1-v8gbf_1  |   PROPOSAL_FILES_TRAIN: ()
# algo-1-v8gbf_1  |   TEST: ('coco_2017_val',)
# algo-1-v8gbf_1  |   TRAIN: ('coco_2017_train',)
# algo-1-v8gbf_1  | GLOBAL:
# algo-1-v8gbf_1  |   HACK: 1.0
# algo-1-v8gbf_1  | INPUT:
# algo-1-v8gbf_1  |   CROP:
# algo-1-v8gbf_1  |     ENABLED: False
# algo-1-v8gbf_1  |     SIZE: [0.9, 0.9]
# algo-1-v8gbf_1  |     TYPE: relative_range
# algo-1-v8gbf_1  |   FORMAT: BGR
# algo-1-v8gbf_1  |   MASK_FORMAT: polygon
# algo-1-v8gbf_1  |   MAX_SIZE_TEST: 1333
# algo-1-v8gbf_1  |   MAX_SIZE_TRAIN: 1333
# algo-1-v8gbf_1  |   MIN_SIZE_TEST: 800
# algo-1-v8gbf_1  |   MIN_SIZE_TRAIN: (640, 672, 704, 736, 768, 800)
# algo-1-v8gbf_1  |   MIN_SIZE_TRAIN_SAMPLING: choice
# algo-1-v8gbf_1  | MODEL:
# algo-1-v8gbf_1  |   ANCHOR_GENERATOR:
# algo-1-v8gbf_1  |     ANGLES: [[-90, 0, 90]]
# algo-1-v8gbf_1  |     ASPECT_RATIOS: [[0.5, 1.0, 2.0]]
# algo-1-v8gbf_1  |     NAME: DefaultAnchorGenerator
# algo-1-v8gbf_1  |     OFFSET: 0.0
# algo-1-v8gbf_1  |     SIZES: [[32, 64, 128, 256, 512]]
# algo-1-v8gbf_1  |   BACKBONE:
# algo-1-v8gbf_1  |     FREEZE_AT: 2
# algo-1-v8gbf_1  |     NAME: build_resnet_backbone
# algo-1-v8gbf_1  |   DEVICE: cuda
# algo-1-v8gbf_1  |   FPN:
# algo-1-v8gbf_1  |     FUSE_TYPE: sum
# algo-1-v8gbf_1  |     IN_FEATURES: []
# algo-1-v8gbf_1  |     NORM:
# algo-1-v8gbf_1  |     OUT_CHANNELS: 256
# algo-1-v8gbf_1  |   KEYPOINT_ON: False
# algo-1-v8gbf_1  |   LOAD_PROPOSALS: False
# algo-1-v8gbf_1  |   MASK_ON: True
# algo-1-v8gbf_1  |   META_ARCHITECTURE: GeneralizedRCNN
# algo-1-v8gbf_1  |   PANOPTIC_FPN:
# algo-1-v8gbf_1  |     COMBINE:
# algo-1-v8gbf_1  |       ENABLED: True
# algo-1-v8gbf_1  |       INSTANCES_CONFIDENCE_THRESH: 0.5
# algo-1-v8gbf_1  |       OVERLAP_THRESH: 0.5
# algo-1-v8gbf_1  |       STUFF_AREA_LIMIT: 4096
# algo-1-v8gbf_1  |     INSTANCE_LOSS_WEIGHT: 1.0
# algo-1-v8gbf_1  |   PIXEL_MEAN: [103.53, 116.28, 123.675]
# algo-1-v8gbf_1  |   PIXEL_STD: [1.0, 1.0, 1.0]
# algo-1-v8gbf_1  |   PROPOSAL_GENERATOR:
# algo-1-v8gbf_1  |     MIN_SIZE: 0
# algo-1-v8gbf_1  |     NAME: RPN
# algo-1-v8gbf_1  |   RESNETS:
# algo-1-v8gbf_1  |     DEFORM_MODULATED: False
# algo-1-v8gbf_1  |     DEFORM_NUM_GROUPS: 1
# algo-1-v8gbf_1  |     DEFORM_ON_PER_STAGE: [False, False, False, False]
# algo-1-v8gbf_1  |     DEPTH: 101
# algo-1-v8gbf_1  |     NORM: FrozenBN
# algo-1-v8gbf_1  |     NUM_GROUPS: 1
# algo-1-v8gbf_1  |     OUT_FEATURES: ['res4']
# algo-1-v8gbf_1  |     RES2_OUT_CHANNELS: 256
# algo-1-v8gbf_1  |     RES5_DILATION: 1
# algo-1-v8gbf_1  |     STEM_OUT_CHANNELS: 64
# algo-1-v8gbf_1  |     STRIDE_IN_1X1: True
# algo-1-v8gbf_1  |     WIDTH_PER_GROUP: 64
# algo-1-v8gbf_1  |   RETINANET:
# algo-1-v8gbf_1  |     BBOX_REG_WEIGHTS: (1.0, 1.0, 1.0, 1.0)
# algo-1-v8gbf_1  |     FOCAL_LOSS_ALPHA: 0.25
# algo-1-v8gbf_1  |     FOCAL_LOSS_GAMMA: 2.0
# algo-1-v8gbf_1  |     IN_FEATURES: ['p3', 'p4', 'p5', 'p6', 'p7']
# algo-1-v8gbf_1  |     IOU_LABELS: [0, -1, 1]
# algo-1-v8gbf_1  |     IOU_THRESHOLDS: [0.4, 0.5]
# algo-1-v8gbf_1  |     NMS_THRESH_TEST: 0.5
# algo-1-v8gbf_1  |     NUM_CLASSES: 80
# algo-1-v8gbf_1  |     NUM_CONVS: 4
# algo-1-v8gbf_1  |     PRIOR_PROB: 0.01
# algo-1-v8gbf_1  |     SCORE_THRESH_TEST: 0.05
# algo-1-v8gbf_1  |     SMOOTH_L1_LOSS_BETA: 0.1
# algo-1-v8gbf_1  |     TOPK_CANDIDATES_TEST: 1000
# algo-1-v8gbf_1  |   ROI_BOX_CASCADE_HEAD:
# algo-1-v8gbf_1  |     BBOX_REG_WEIGHTS: ((10.0, 10.0, 5.0, 5.0), (20.0, 20.0, 10.0, 10.0), (30.0, 30.0, 15.0, 15.0))
# algo-1-v8gbf_1  |     IOUS: (0.5, 0.6, 0.7)
# algo-1-v8gbf_1  |   ROI_BOX_HEAD:
# algo-1-v8gbf_1  |     BBOX_REG_WEIGHTS: (10.0, 10.0, 5.0, 5.0)
# algo-1-v8gbf_1  |     CLS_AGNOSTIC_BBOX_REG: False
# algo-1-v8gbf_1  |     CONV_DIM: 256
# algo-1-v8gbf_1  |     FC_DIM: 1024
# algo-1-v8gbf_1  |     NAME:
# algo-1-v8gbf_1  |     NORM:
# algo-1-v8gbf_1  |     NUM_CONV: 0
# algo-1-v8gbf_1  |     NUM_FC: 0
# algo-1-v8gbf_1  |     POOLER_RESOLUTION: 14
# algo-1-v8gbf_1  |     POOLER_SAMPLING_RATIO: 0
# algo-1-v8gbf_1  |     POOLER_TYPE: ROIAlignV2
# algo-1-v8gbf_1  |     SMOOTH_L1_BETA: 0.0
# algo-1-v8gbf_1  |     TRAIN_ON_PRED_BOXES: False
# algo-1-v8gbf_1  |   ROI_HEADS:
# algo-1-v8gbf_1  |     BATCH_SIZE_PER_IMAGE: 512
# algo-1-v8gbf_1  |     IN_FEATURES: ['res4']
# algo-1-v8gbf_1  |     IOU_LABELS: [0, 1]
# algo-1-v8gbf_1  |     IOU_THRESHOLDS: [0.5]
# algo-1-v8gbf_1  |     NAME: Res5ROIHeads
# algo-1-v8gbf_1  |     NMS_THRESH_TEST: 0.5
# algo-1-v8gbf_1  |     NUM_CLASSES: 80
# algo-1-v8gbf_1  |     POSITIVE_FRACTION: 0.25
# algo-1-v8gbf_1  |     PROPOSAL_APPEND_GT: True
# algo-1-v8gbf_1  |     SCORE_THRESH_TEST: 0.05
# algo-1-v8gbf_1  |   ROI_KEYPOINT_HEAD:
# algo-1-v8gbf_1  |     CONV_DIMS: (512, 512, 512, 512, 512, 512, 512, 512)
# algo-1-v8gbf_1  |     LOSS_WEIGHT: 1.0
# algo-1-v8gbf_1  |     MIN_KEYPOINTS_PER_IMAGE: 1
# algo-1-v8gbf_1  |     NAME: KRCNNConvDeconvUpsampleHead
# algo-1-v8gbf_1  |     NORMALIZE_LOSS_BY_VISIBLE_KEYPOINTS: True
# algo-1-v8gbf_1  |     NUM_KEYPOINTS: 17
# algo-1-v8gbf_1  |     POOLER_RESOLUTION: 14
# algo-1-v8gbf_1  |     POOLER_SAMPLING_RATIO: 0
# algo-1-v8gbf_1  |     POOLER_TYPE: ROIAlignV2
# algo-1-v8gbf_1  |   ROI_MASK_HEAD:
# algo-1-v8gbf_1  |     CLS_AGNOSTIC_MASK: False
# algo-1-v8gbf_1  |     CONV_DIM: 256
# algo-1-v8gbf_1  |     NAME: MaskRCNNConvUpsampleHead
# algo-1-v8gbf_1  |     NORM:
# algo-1-v8gbf_1  |     NUM_CONV: 0
# algo-1-v8gbf_1  |     POOLER_RESOLUTION: 14
# algo-1-v8gbf_1  |     POOLER_SAMPLING_RATIO: 0
# algo-1-v8gbf_1  |     POOLER_TYPE: ROIAlignV2
# algo-1-v8gbf_1  |   RPN:
# algo-1-v8gbf_1  |     BATCH_SIZE_PER_IMAGE: 256
# algo-1-v8gbf_1  |     BBOX_REG_WEIGHTS: (1.0, 1.0, 1.0, 1.0)
# algo-1-v8gbf_1  |     BOUNDARY_THRESH: -1
# algo-1-v8gbf_1  |     HEAD_NAME: StandardRPNHead
# algo-1-v8gbf_1  |     IN_FEATURES: ['res4']
# algo-1-v8gbf_1  |     IOU_LABELS: [0, -1, 1]
# algo-1-v8gbf_1  |     IOU_THRESHOLDS: [0.3, 0.7]
# algo-1-v8gbf_1  |     LOSS_WEIGHT: 1.0
# algo-1-v8gbf_1  |     NMS_THRESH: 0.7
# algo-1-v8gbf_1  |     POSITIVE_FRACTION: 0.5
# algo-1-v8gbf_1  |     POST_NMS_TOPK_TEST: 1000
# algo-1-v8gbf_1  |     POST_NMS_TOPK_TRAIN: 2000
# algo-1-v8gbf_1  |     PRE_NMS_TOPK_TEST: 6000
# algo-1-v8gbf_1  |     PRE_NMS_TOPK_TRAIN: 12000
# algo-1-v8gbf_1  |     SMOOTH_L1_BETA: 0.0
# algo-1-v8gbf_1  |   SEM_SEG_HEAD:
# algo-1-v8gbf_1  |     COMMON_STRIDE: 4
# algo-1-v8gbf_1  |     CONVS_DIM: 128
# algo-1-v8gbf_1  |     IGNORE_VALUE: 255
# algo-1-v8gbf_1  |     IN_FEATURES: ['p2', 'p3', 'p4', 'p5']
# algo-1-v8gbf_1  |     LOSS_WEIGHT: 1.0
# algo-1-v8gbf_1  |     NAME: SemSegFPNHead
# algo-1-v8gbf_1  |     NORM: GN
# algo-1-v8gbf_1  |     NUM_CLASSES: 54
# algo-1-v8gbf_1  |   WEIGHTS: detectron2://ImageNetPretrained/MSRA/R-101.pkl
# algo-1-v8gbf_1  | OUTPUT_DIR: /opt/ml/output/data
# algo-1-v8gbf_1  | SEED: -1
# algo-1-v8gbf_1  | SOLVER:
# algo-1-v8gbf_1  |   BASE_LR: 0.02
# algo-1-v8gbf_1  |   BIAS_LR_FACTOR: 1.0
# algo-1-v8gbf_1  |   CHECKPOINT_PERIOD: 5000
# algo-1-v8gbf_1  |   CLIP_GRADIENTS:
# algo-1-v8gbf_1  |     CLIP_TYPE: value
# algo-1-v8gbf_1  |     CLIP_VALUE: 1.0
# algo-1-v8gbf_1  |     ENABLED: False
# algo-1-v8gbf_1  |     NORM_TYPE: 2.0
# algo-1-v8gbf_1  |   GAMMA: 0.1
# algo-1-v8gbf_1  |   IMS_PER_BATCH: 1
# algo-1-v8gbf_1  |   LR_SCHEDULER_NAME: WarmupMultiStepLR
# algo-1-v8gbf_1  |   MAX_ITER: 270000
# algo-1-v8gbf_1  |   MOMENTUM: 0.9
# algo-1-v8gbf_1  |   STEPS: (210000, 250000)
# algo-1-v8gbf_1  |   WARMUP_FACTOR: 0.001
# algo-1-v8gbf_1  |   WARMUP_ITERS: 1000
# algo-1-v8gbf_1  |   WARMUP_METHOD: linear
# algo-1-v8gbf_1  |   WEIGHT_DECAY: 0.0001
# algo-1-v8gbf_1  |   WEIGHT_DECAY_BIAS: 0.0001
# algo-1-v8gbf_1  |   WEIGHT_DECAY_NORM: 0.0
# algo-1-v8gbf_1  | TEST:
# algo-1-v8gbf_1  |   AUG:
# algo-1-v8gbf_1  |     ENABLED: False
# algo-1-v8gbf_1  |     FLIP: True
# algo-1-v8gbf_1  |     MAX_SIZE: 4000
# algo-1-v8gbf_1  |     MIN_SIZES: (400, 500, 600, 700, 800, 900, 1000, 1100, 1200)
# algo-1-v8gbf_1  |   DETECTIONS_PER_IMAGE: 100
# algo-1-v8gbf_1  |   EVAL_PERIOD: 0
# algo-1-v8gbf_1  |   EXPECTED_RESULTS: []
# algo-1-v8gbf_1  |   KEYPOINT_OKS_SIGMAS: []
# algo-1-v8gbf_1  |   PRECISE_BN:
# algo-1-v8gbf_1  |     ENABLED: False
# algo-1-v8gbf_1  |     NUM_ITER: 200
# algo-1-v8gbf_1  | VERSION: 2
# algo-1-v8gbf_1  | VIS_PERIOD: 0
# algo-1-v8gbf_1  | [04/28 20:16:51 detectron2]: Full config saved to /opt/ml/output/data/config.yaml
# algo-1-v8gbf_1  | [04/28 20:16:51 detectron2]: Full config saved to /opt/ml/output/data/config.yaml
# algo-1-v8gbf_1  | [04/28 20:16:51 d2.utils.env]: Using a generated random seed 51539205
# algo-1-v8gbf_1  | [04/28 20:16:51 d2.utils.env]: Using a generated random seed 51539205
# algo-1-v8gbf_1  | [04/28 20:16:54 fvcore.common.checkpoint]: Loading checkpoint from detectron2://ImageNetPretrained/MSRA/R-101.pkl
# algo-1-v8gbf_1  | [04/28 20:16:54 fvcore.common.file_io]: Downloading https://dl.fbaipublicfiles.com/detectron2/ImageNetPretrained/MSRA/R-101.pkl ...
# algo-1-v8gbf_1  | [04/28 20:16:54 fvcore.common.download]: Downloading from https://dl.fbaipublicfiles.com/detectron2/ImageNetPretrained/MSRA/R-101.pkl ...
# algo-1-v8gbf_1  | [04/28 20:17:02 fvcore.common.download]: Successfully downloaded /tmp/detectron2/ImageNetPretrained/MSRA/R-101.pkl. 178666803 bytes.
# algo-1-v8gbf_1  | [04/28 20:17:02 fvcore.common.file_io]: URL https://dl.fbaipublicfiles.com/detectron2/ImageNetPretrained/MSRA/R-101.pkl cached in /tmp/detectron2/ImageNetPretrained/MSRA/R-101.pkl
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: Remapping C2 weights ......
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: Remapping C2 weights ......
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv1.norm.bias                      loaded from res2_0_branch2a_bn_beta           of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv1.norm.bias                      loaded from res2_0_branch2a_bn_beta           of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv1.norm.running_mean              loaded from res2_0_branch2a_bn_running_mean   of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv1.norm.running_mean              loaded from res2_0_branch2a_bn_running_mean   of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv1.norm.running_var               loaded from res2_0_branch2a_bn_running_var    of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv1.norm.running_var               loaded from res2_0_branch2a_bn_running_var    of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv1.norm.weight                    loaded from res2_0_branch2a_bn_gamma          of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv1.norm.weight                    loaded from res2_0_branch2a_bn_gamma          of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv1.weight                         loaded from res2_0_branch2a_w                 of shape (64, 64, 1, 1)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv1.weight                         loaded from res2_0_branch2a_w                 of shape (64, 64, 1, 1)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv2.norm.bias                      loaded from res2_0_branch2b_bn_beta           of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv2.norm.bias                      loaded from res2_0_branch2b_bn_beta           of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv2.norm.running_mean              loaded from res2_0_branch2b_bn_running_mean   of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv2.norm.running_mean              loaded from res2_0_branch2b_bn_running_mean   of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv2.norm.running_var               loaded from res2_0_branch2b_bn_running_var    of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv2.norm.running_var               loaded from res2_0_branch2b_bn_running_var    of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv2.norm.weight                    loaded from res2_0_branch2b_bn_gamma          of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv2.norm.weight                    loaded from res2_0_branch2b_bn_gamma          of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv2.weight                         loaded from res2_0_branch2b_w                 of shape (64, 64, 3, 3)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv2.weight                         loaded from res2_0_branch2b_w                 of shape (64, 64, 3, 3)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv3.norm.bias                      loaded from res2_0_branch2c_bn_beta           of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv3.norm.bias                      loaded from res2_0_branch2c_bn_beta           of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv3.norm.running_mean              loaded from res2_0_branch2c_bn_running_mean   of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv3.norm.running_mean              loaded from res2_0_branch2c_bn_running_mean   of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv3.norm.running_var               loaded from res2_0_branch2c_bn_running_var    of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv3.norm.running_var               loaded from res2_0_branch2c_bn_running_var    of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv3.norm.weight                    loaded from res2_0_branch2c_bn_gamma          of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv3.norm.weight                    loaded from res2_0_branch2c_bn_gamma          of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv3.weight                         loaded from res2_0_branch2c_w                 of shape (256, 64, 1, 1)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.conv3.weight                         loaded from res2_0_branch2c_w                 of shape (256, 64, 1, 1)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.shortcut.norm.bias                   loaded from res2_0_branch1_bn_beta            of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.shortcut.norm.bias                   loaded from res2_0_branch1_bn_beta            of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.shortcut.norm.running_mean           loaded from res2_0_branch1_bn_running_mean    of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.shortcut.norm.running_mean           loaded from res2_0_branch1_bn_running_mean    of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.shortcut.norm.running_var            loaded from res2_0_branch1_bn_running_var     of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.shortcut.norm.running_var            loaded from res2_0_branch1_bn_running_var     of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.shortcut.norm.weight                 loaded from res2_0_branch1_bn_gamma           of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.shortcut.norm.weight                 loaded from res2_0_branch1_bn_gamma           of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.shortcut.weight                      loaded from res2_0_branch1_w                  of shape (256, 64, 1, 1)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.0.shortcut.weight                      loaded from res2_0_branch1_w                  of shape (256, 64, 1, 1)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv1.norm.bias                      loaded from res2_1_branch2a_bn_beta           of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv1.norm.bias                      loaded from res2_1_branch2a_bn_beta           of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv1.norm.running_mean              loaded from res2_1_branch2a_bn_running_mean   of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv1.norm.running_mean              loaded from res2_1_branch2a_bn_running_mean   of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv1.norm.running_var               loaded from res2_1_branch2a_bn_running_var    of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv1.norm.running_var               loaded from res2_1_branch2a_bn_running_var    of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv1.norm.weight                    loaded from res2_1_branch2a_bn_gamma          of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv1.norm.weight                    loaded from res2_1_branch2a_bn_gamma          of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv1.weight                         loaded from res2_1_branch2a_w                 of shape (64, 256, 1, 1)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv1.weight                         loaded from res2_1_branch2a_w                 of shape (64, 256, 1, 1)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv2.norm.bias                      loaded from res2_1_branch2b_bn_beta           of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv2.norm.bias                      loaded from res2_1_branch2b_bn_beta           of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv2.norm.running_mean              loaded from res2_1_branch2b_bn_running_mean   of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv2.norm.running_mean              loaded from res2_1_branch2b_bn_running_mean   of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv2.norm.running_var               loaded from res2_1_branch2b_bn_running_var    of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv2.norm.running_var               loaded from res2_1_branch2b_bn_running_var    of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv2.norm.weight                    loaded from res2_1_branch2b_bn_gamma          of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv2.norm.weight                    loaded from res2_1_branch2b_bn_gamma          of shape (64,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv2.weight                         loaded from res2_1_branch2b_w                 of shape (64, 64, 3, 3)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv2.weight                         loaded from res2_1_branch2b_w                 of shape (64, 64, 3, 3)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv3.norm.bias                      loaded from res2_1_branch2c_bn_beta           of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv3.norm.bias                      loaded from res2_1_branch2c_bn_beta           of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv3.norm.running_mean              loaded from res2_1_branch2c_bn_running_mean   of shape (256,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: backbone.res2.1.conv3.norm.running_mean              loaded from res2_1_branch2c_bn_running_mean   of shape (256,)
# ...
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.1.conv3.norm.bias                     loaded from res5_1_branch2c_bn_beta           of shape (2048,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.1.conv3.norm.running_mean             loaded from res5_1_branch2c_bn_running_mean   of shape (2048,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.1.conv3.norm.running_mean             loaded from res5_1_branch2c_bn_running_mean   of shape (2048,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.1.conv3.norm.running_var              loaded from res5_1_branch2c_bn_running_var    of shape (2048,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.1.conv3.norm.running_var              loaded from res5_1_branch2c_bn_running_var    of shape (2048,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.1.conv3.norm.weight                   loaded from res5_1_branch2c_bn_gamma          of shape (2048,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.1.conv3.norm.weight                   loaded from res5_1_branch2c_bn_gamma          of shape (2048,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.1.conv3.weight                        loaded from res5_1_branch2c_w                 of shape (2048, 512, 1, 1)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.1.conv3.weight                        loaded from res5_1_branch2c_w                 of shape (2048, 512, 1, 1)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv1.norm.bias                     loaded from res5_2_branch2a_bn_beta           of shape (512,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv1.norm.bias                     loaded from res5_2_branch2a_bn_beta           of shape (512,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv1.norm.running_mean             loaded from res5_2_branch2a_bn_running_mean   of shape (512,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv1.norm.running_mean             loaded from res5_2_branch2a_bn_running_mean   of shape (512,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv1.norm.running_var              loaded from res5_2_branch2a_bn_running_var    of shape (512,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv1.norm.running_var              loaded from res5_2_branch2a_bn_running_var    of shape (512,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv1.norm.weight                   loaded from res5_2_branch2a_bn_gamma          of shape (512,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv1.norm.weight                   loaded from res5_2_branch2a_bn_gamma          of shape (512,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv1.weight                        loaded from res5_2_branch2a_w                 of shape (512, 2048, 1, 1)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv1.weight                        loaded from res5_2_branch2a_w                 of shape (512, 2048, 1, 1)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv2.norm.bias                     loaded from res5_2_branch2b_bn_beta           of shape (512,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv2.norm.bias                     loaded from res5_2_branch2b_bn_beta           of shape (512,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv2.norm.running_mean             loaded from res5_2_branch2b_bn_running_mean   of shape (512,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv2.norm.running_mean             loaded from res5_2_branch2b_bn_running_mean   of shape (512,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv2.norm.running_var              loaded from res5_2_branch2b_bn_running_var    of shape (512,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv2.norm.running_var              loaded from res5_2_branch2b_bn_running_var    of shape (512,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv2.norm.weight                   loaded from res5_2_branch2b_bn_gamma          of shape (512,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv2.norm.weight                   loaded from res5_2_branch2b_bn_gamma          of shape (512,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv2.weight                        loaded from res5_2_branch2b_w                 of shape (512, 512, 3, 3)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv2.weight                        loaded from res5_2_branch2b_w                 of shape (512, 512, 3, 3)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv3.norm.bias                     loaded from res5_2_branch2c_bn_beta           of shape (2048,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv3.norm.bias                     loaded from res5_2_branch2c_bn_beta           of shape (2048,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv3.norm.running_mean             loaded from res5_2_branch2c_bn_running_mean   of shape (2048,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv3.norm.running_mean             loaded from res5_2_branch2c_bn_running_mean   of shape (2048,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv3.norm.running_var              loaded from res5_2_branch2c_bn_running_var    of shape (2048,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv3.norm.running_var              loaded from res5_2_branch2c_bn_running_var    of shape (2048,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv3.norm.weight                   loaded from res5_2_branch2c_bn_gamma          of shape (2048,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv3.norm.weight                   loaded from res5_2_branch2c_bn_gamma          of shape (2048,)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv3.weight                        loaded from res5_2_branch2c_w                 of shape (2048, 512, 1, 1)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: roi_heads.res5.2.conv3.weight                        loaded from res5_2_branch2c_w                 of shape (2048, 512, 1, 1)
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: Some model parameters or buffers are not in the checkpoint:
# algo-1-v8gbf_1  |   pixel_mean
# algo-1-v8gbf_1  |   pixel_std
# algo-1-v8gbf_1  |   proposal_generator.anchor_generator.cell_anchors.0
# algo-1-v8gbf_1  |   proposal_generator.rpn_head.anchor_deltas.{bias, weight}
# algo-1-v8gbf_1  |   proposal_generator.rpn_head.conv.{bias, weight}
# algo-1-v8gbf_1  |   proposal_generator.rpn_head.objectness_logits.{bias, weight}
# algo-1-v8gbf_1  |   roi_heads.box_predictor.bbox_pred.{bias, weight}
# algo-1-v8gbf_1  |   roi_heads.box_predictor.cls_score.{bias, weight}
# algo-1-v8gbf_1  |   roi_heads.mask_head.deconv.{bias, weight}
# algo-1-v8gbf_1  |   roi_heads.mask_head.predictor.{bias, weight}
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: Some model parameters or buffers are not in the checkpoint:
# algo-1-v8gbf_1  |   pixel_mean
# algo-1-v8gbf_1  |   pixel_std
# algo-1-v8gbf_1  |   proposal_generator.anchor_generator.cell_anchors.0
# algo-1-v8gbf_1  |   proposal_generator.rpn_head.anchor_deltas.{bias, weight}
# algo-1-v8gbf_1  |   proposal_generator.rpn_head.conv.{bias, weight}
# algo-1-v8gbf_1  |   proposal_generator.rpn_head.objectness_logits.{bias, weight}
# algo-1-v8gbf_1  |   roi_heads.box_predictor.bbox_pred.{bias, weight}
# algo-1-v8gbf_1  |   roi_heads.box_predictor.cls_score.{bias, weight}
# algo-1-v8gbf_1  |   roi_heads.mask_head.deconv.{bias, weight}
# algo-1-v8gbf_1  |   roi_heads.mask_head.predictor.{bias, weight}
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: The checkpoint state_dict contains keys that are not used by the model:
# algo-1-v8gbf_1  |   fc1000_b
# algo-1-v8gbf_1  |   fc1000_w
# algo-1-v8gbf_1  | [04/28 20:17:02 d2.checkpoint.c2_model_loading]: The checkpoint state_dict contains keys that are not used by the model:
# algo-1-v8gbf_1  |   fc1000_b
# algo-1-v8gbf_1  |   fc1000_w
# algo-1-v8gbf_1  | 2020-04-28 20:17:03,720 sagemaker-containers ERROR    ExecuteUserScriptError:
# algo-1-v8gbf_1  | Command "/opt/conda/bin/python train_coco.py --config-file COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml --eval-only False --resume False"
# R-101.pkl: 179MB [00:07, 22.7MB/s]                           :07<00:00, 26.7MB/s]
# algo-1-v8gbf_1  | Traceback (most recent call last):
# algo-1-v8gbf_1  |   File "train_coco.py", line 307, in <module>
# algo-1-v8gbf_1  |     args=(sm_args,),
# algo-1-v8gbf_1  |   File "/opt/conda/lib/python3.6/site-packages/detectron2/engine/launch.py", line 57, in launch
# algo-1-v8gbf_1  |     main_func(*args)
# algo-1-v8gbf_1  |   File "train_coco.py", line 265, in main
# algo-1-v8gbf_1  |     do_train(cfg, model, resume=resume)
# algo-1-v8gbf_1  |   File "train_coco.py", line 204, in do_train
# algo-1-v8gbf_1  |     data_loader = build_detection_train_loader(cfg)
# algo-1-v8gbf_1  |   File "/opt/conda/lib/python3.6/site-packages/detectron2/data/build.py", line 297, in build_detection_train_loader
# algo-1-v8gbf_1  |     proposal_files=cfg.DATASETS.PROPOSAL_FILES_TRAIN if cfg.MODEL.LOAD_PROPOSALS else None,
# algo-1-v8gbf_1  |   File "/opt/conda/lib/python3.6/site-packages/detectron2/data/build.py", line 224, in get_detection_dataset_dicts
# algo-1-v8gbf_1  |     dataset_dicts = [DatasetCatalog.get(dataset_name) for dataset_name in dataset_names]
# algo-1-v8gbf_1  |   File "/opt/conda/lib/python3.6/site-packages/detectron2/data/build.py", line 224, in <listcomp>
# algo-1-v8gbf_1  |     dataset_dicts = [DatasetCatalog.get(dataset_name) for dataset_name in dataset_names]
# algo-1-v8gbf_1  |   File "/opt/conda/lib/python3.6/site-packages/detectron2/data/catalog.py", line 62, in get
# algo-1-v8gbf_1  |     return f()
# algo-1-v8gbf_1  |   File "/opt/conda/lib/python3.6/site-packages/detectron2/data/datasets/register_coco.py", line 37, in <lambda>
# algo-1-v8gbf_1  |     DatasetCatalog.register(name, lambda: load_coco_json(json_file, image_root, name))
# algo-1-v8gbf_1  |   File "/opt/conda/lib/python3.6/site-packages/detectron2/data/datasets/coco.py", line 58, in load_coco_json
# algo-1-v8gbf_1  |     coco_api = COCO(json_file)
# algo-1-v8gbf_1  |   File "/opt/conda/lib/python3.6/site-packages/pycocotools/coco.py", line 84, in __init__
# algo-1-v8gbf_1  |     dataset = json.load(open(annotation_file, 'r'))
# algo-1-v8gbf_1  | FileNotFoundError: [Errno 2] No such file or directory: '/opt/ml/input/data/training/coco/annotations/instances_train2017.json'
# tmp6oge1eha_algo-1-v8gbf_1 exited with code 1
# Aborting on container exit...
# Failed to delete: /tmp/tmp6oge1eha/algo-1-v8gbf Please remove it manually.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/local/image.py in train(self, input_data_config, output_data_config, hyperparameters, job_name)
#     160         try:
# --> 161             _stream_output(process)
#     162         except RuntimeError as e:
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/local/image.py in _stream_output(process)
#     676     if exit_code != 0:
# --> 677         raise RuntimeError("Process exited with code: %s" % exit_code)
#     678
#
# RuntimeError: Process exited with code: 1
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-41-9bc00e4f4fb6> in <module>()
#      22
#      23 #d2.fit({'training':"s3://coco2017-2a27f"}, wait=False)
# ---> 24 d2.fit()
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     472         self._prepare_for_training(job_name=job_name)
#     473
# --> 474         self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#     475         self.jobs.append(self.latest_training_job)
#     476         if wait:
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/estimator.py in start_new(cls, estimator, inputs, experiment_config)
#    1039             train_args["enable_sagemaker_metrics"] = estimator.enable_sagemaker_metrics
#    1040
# -> 1041         estimator.sagemaker_session.train(**train_args)
#    1042
#    1043         return cls(estimator.sagemaker_session, estimator._current_job_name)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/session.py in train(self, input_mode, input_config, role, job_name, output_config, resource_config, vpc_config, hyperparameters, stop_condition, tags, metric_definitions, enable_network_isolation, image, algorithm_arn, encrypt_inter_container_traffic, train_use_spot_instances, checkpoint_s3_uri, checkpoint_local_path, experiment_config, debugger_rule_configs, debugger_hook_config, tensorboard_output_config, enable_sagemaker_metrics)
#     588         LOGGER.info("Creating training-job with name: %s", job_name)
#     589         LOGGER.debug("train request: %s", json.dumps(train_request, indent=4))
# --> 590         self.sagemaker_client.create_training_job(**train_request)
#     591
#     592     def process(
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/local/local_session.py in create_training_job(self, TrainingJobName, AlgorithmSpecification, OutputDataConfig, ResourceConfig, InputDataConfig, **kwargs)
#     100         hyperparameters = kwargs["HyperParameters"] if "HyperParameters" in kwargs else {}
#     101         logger.info("Starting training job")
# --> 102         training_job.start(InputDataConfig, OutputDataConfig, hyperparameters, TrainingJobName)
#     103
#     104         LocalSagemakerClient._training_jobs[TrainingJobName] = training_job
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/local/entities.py in start(self, input_data_config, output_data_config, hyperparameters, job_name)
#      94
#      95         self.model_artifacts = self.container.train(
# ---> 96             input_data_config, output_data_config, hyperparameters, job_name
#      97         )
#      98         self.end_time = datetime.datetime.now()
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/local/image.py in train(self, input_data_config, output_data_config, hyperparameters, job_name)
#     164             # which contains the exit code and append the command line to it.
#     165             msg = "Failed to run: %s, %s" % (compose_command, str(e))
# --> 166             raise RuntimeError(msg)
#     167         finally:
#     168             artifacts = self.retrieve_artifacts(compose_data, output_data_config, job_name)
#
# RuntimeError: Failed to run: ['docker-compose', '-f', '/tmp/tmp6oge1eha/docker-compose.yaml', 'up', '--build', '--abort-on-container-exit'], Process exited with code: 1

# %% [markdown]
# ## Training with Spot Instance

# %%
train_use_spot_instances = True
train_max_run=21600
train_max_wait = 30000 if train_use_spot_instances else None

import uuid
checkpoint_suffix = str(uuid.uuid4())[:8]
checkpoint_s3_uri = 's3://{}/artifacts/mxnet-checkpoint-{}/'.format(bucket, checkpoint_suffix) if train_use_spot_instances else None

# %%
container = "d2-sm-coco-custom" # your container name
image = '{}.dkr.ecr.{}.amazonaws.com/{}:latest'.format(account, region, container)

hyperparameters = {"config-file":"COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_1x.yaml", 
                   "resume":"False", # whether to re-use weights from pre-trained model
                   "eval-only":"False", # whether to perform only D2 model evaluation
                  # opts are D2 model configuration as defined here: https://detectron2.readthedocs.io/modules/config.html#config-references
                  # this is a way to override default D2 configuration from Sagemaker API
                  "opts": "SOLVER.BASE_LR 0.00025 \
                           MODEL.ROI_HEADS.NUM_CLASSES 80 \
                           DATALOADER.NUM_WORKERS 4"
                  }

d2 = sagemaker.estimator.Estimator(image,
                                   role=role,
                                   train_instance_count=2, 
                                   train_instance_type='ml.p3.16xlarge',
#                                   train_instance_type="local_gpu", # use local_gpu for quick troubleshooting
                                   train_volume_size=100,
                                   output_path="s3://{}/{}".format(sess.default_bucket(), prefix_output),
                                   metric_definitions = metric_definitions,
                                   hyperparameters = hyperparameters, 
                                   tags=[{"Key":"Desc", "Value":"spot training"}],
                                   sagemaker_session=sess,
                                   train_use_spot_instances=train_use_spot_instances,
                                   train_max_run=train_max_run,
                                   train_max_wait=train_max_wait,
                                   checkpoint_s3_uri=checkpoint_s3_uri)

d2.fit({'training':"s3://coco2017-2a27f"}, wait=False)
